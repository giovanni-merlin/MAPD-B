# %% [markdown]
# # Lecture 3: Spark Streaming
#
# _Spark Streaming_ is an extension of the Spark API that enables scalabe stream processing.
#
# The continous stream of input data can be ingested from many data sources such as **Kafka**, **Amazon s3** or **TCP sockets**.
#
# The Spark API allows to process data via high-level functions such as *map* and *reduce*. As we are going to see, it is also possible to use dataframe operations.
#
# Processed data can be exported to an external database and used to make live dashboards or offline analyses, or stored in files, or be used in a further stage of a Kafka pipeline.
#
# Overall, the practice of reading data from a set of sources, pre-process it, and then store it in a different format for later analysis is extremely common, and has its own name: **realtime ETL pipelines**.
# - **E**xtract
# - **T**transform
# - **L**oad

# %% [markdown]
# Spark streaming works by dividing the input data into _micro-batches_ that can be treated as static datasets. In Spark this is referred to as a *discretized stream* (*DStream*). The DStream is represented using RDDs.
#
# ![DStream](imgs/lecture3/DStream.png)
#
# Any transformation applied on the DStream, i.e. anything like a `Dstream.map()`, will act independently on each batch. For example, in the image below, we can filter the original RDD to remove some data and produce a new stream.
#
# ![DStream_filter](imgs/lecture3/Dstream_filter.png)
#
# In this lecture we will see how to setup a simple stream using a TCP socket as a data source.

# %% [markdown]
# ## Create and Start a Spark Session

# %%
# import the python libraries to create/connect to a Spark Session
from pyspark.sql import SparkSession

# build a SparkSession 
#   connect to the master node on the port where the master node is listening (7077)
#   declare the app name 
#   configure the executor memory to 512 MB
#   either *connect* or *create* a new Spark Context
spark = SparkSession.builder \
    .master("spark://spark-master:7077")\
    .appName("My streaming spark application")\
    .config("spark.executor.memory", "512m")\
    .config("spark.sql.execution.arrow.pyspark.enabled", "true")\
    .config("spark.sql.execution.arrow.pyspark.fallback.enabled", "false")\
    .getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://30bc87cf2bde:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.3.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>spark://spark-master:7077</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>My streaming spark application</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
# create a spark context
sc = spark.sparkContext

# print its status
sc
# Out:
# <SparkContext master=spark://spark-master:7077 appName=My streaming spark application>

# %% [markdown]
# ## Spark _Streaming_ context
#
# The first step of a Spark streaming application is the creation of a `StreamingContext`.
#
# The `StreamingContext` is a crucial component in Spark Streaming. It's responsible for initializing the Spark Streaming application and specifying how to handle micro-batches of data.
#
# The `StreamingContext` is a similar concept to the `sparkContext` but it requires to be initialized with some additional information to know how to handle the micro-batches.
#
# To create a `StreamingContext`, you can use the `StreamingContext(SparkContext, batch_interval)` constructor. The `SparkContext` object provides the necessary environment for Spark Streaming, while the `batch_interval` parameter determines the (wall-time) duration of each batch in seconds.
#
# It's important to note that you can only have at most **one** `StreamingContext` for each Spark application. Attempting to create multiple `StreamingContext` objects in a single application will result in errors.

# %% [markdown]
# Create a Spark `StreamingContext` with a batch interval of 2 seconds

# %%
from pyspark.streaming import StreamingContext

# create a streaming context with a batch interval of 2 seconds
ssc = StreamingContext(sc, 2)

# %% [markdown]
# ### Starting and Stopping Spark Streaming
#
# To process data in real-time using Spark, we need to create a `StreamingContext`, define the operations to perform on the data, and specify the data source and sink to connect to.
#
# Once the streaming operations are defined, we can start processing the stream by calling the `.start()` method of the `StreamingContext` object (`ssc` in our case). Similarly, we can stop the streaming processing by calling the `.stop()` method.
#
# **NOTE:** It's important to note that when we stop the `StreamingContext`, the default behavior is to also stop the `SparkContext`. This means that the entire Spark application will be closed by default. To prevent this, we can pass the `stopSparkContext=False` option when stopping the `StreamingContext`.

# %% [markdown]
# ### TCP Socket Source
# One to one phone call as for internet
#
# For this example spark will read data from a TCP socket using Spark Streaming.
#
# A TCP socket is a communication endpoint used to establish a connection between two devices over a network.
# You can think of it as a telephone connection: two endpoints have to enstablish a connection; once the connection is enstablished, a communication can occur, with a data transfer; as soon as one of the two ends interrupts the connection the whole communcation is lost.
#
# We will generate a dummy data stream representing fake credit card transactions.
#
# A simple python program will be used to create this data stream.
# You will be able to find it in `utils/producer.py`.
# When executed, the producer will try to enstablish a TCP connection and send data on port `5555` of a given `host` (`spark-master` in our case).
#
# Before executing the producer program, take a moment to review the `producer.py` code to understand how it works. It's important to understand the logic of the program before using it to generate the streaming data.

# %%
! cat utils/producer.py
# Out:
# import socket
# import json
# import time
# import random
# import argparse
#
# # Define some lists of first and last names to use for generating random messages
# first_names=('John','Andy','Joe','Alice','Jill')
# last_names=('Johnson','Smith','Jones', 'Millers','Darby')
#
# # Define a function for sending messages over the socket
# def send_messages(client_socket):
#     try:
#         while 1:
#             # Generate a random message with a random name, surname, amount, delta_t, and flag
#             msg = {
#                 'name': random.choice(first_names),
#                 'surname': random.choice(last_names),
#                 'amount': '{:.2f}'.format(random.random()*1000),
#                 'delta_t': '{:.2f}'.format(random.random()*10),
#                 'flag': random.choices([0,1], weights=[0.8, 0.2])[0]
#             }
#             # Encode the message as JSON and send it over the socket
#             client_socket.send((json.dumps(msg)+"\n").encode('utf-8'))
#             # Sleep for a short amount of time to avoid overwhelming the network
#             time.sleep(0.1)
#
#     except KeyboardInterrupt:
#         # If the user presses Ctrl+C, exit gracefully
#         exit()
#
# if __name__ == "__main__":
#
#     # Parse command-line arguments to determine the hostname to use
#     parser = argparse.ArgumentParser()
#     parser.add_argument('--hostname', type=str, required=True)
#     args = parser.parse_args()
#     print('Using hostname:', args.hostname)
#
#     # Create a new socket and bind it to the specified hostname and port
#     new_skt = socket.socket()
#     host = args.hostname
#     port = 5555
#     new_skt.bind((host, port))
#     print("Now listening on port: %s" % str(port))
#
#     # Wait for a client to connect to the socket
#     new_skt.listen(5) #  waiting for client connection.
#     c, addr = new_skt.accept()
#     print("Received request from: " + str(addr))
#     # connection established, send messaged
#     send_messages(c)

# %% [markdown]
# The producer will generate new records in the form of a random combination of:
# - `name`
# - `surname`
# - `amount`: amount of the credit card transaction
# - `delta_t`: time between transactions
# - `flag`: random flag to indicate if potentially fraudolent or not
#
# These information will be formatted into a `.json` data format

# %% [markdown]
# ### Declaring the `StreamingContext` data source as a TCP socket
#
# To inform Spark that the StreamingContext data source will be a TCP socket located at a specific `hostname` and `port`, we can use the `socketTextStream(hostname, port)` method.
#
# Refer to the [StreamingContext documentation](https://spark.apache.org/docs/latest/api/python/reference/api/pyspark.streaming.StreamingContext.html) for additional available options.

# %%
# the hostname and port number
hostname = "spark-master"
portnumber = 5555

# declare the Spark Streaming source as TCP socket 
socket_stream = ssc.socketTextStream(hostname, portnumber)

# %% [markdown]
# ### Start the python producer.py script
#
# From a terminal/WSL, connect to the `spark-master` Docker container using the command
# ```bash
# docker exec -it spark-master bash
# ```
#
# From inside the docker container, move to the `/mapd-workspace` folder and execute the python script with the option `--hostname spark-master`:
#
# ```bash
# python notebooks/utils/producer.py --hostname spark-master
# ```

# %% [markdown]
# ## Exploring the data stream
#
# The first thing we need to to is load the data describing each transaction, formatted as `json`.

# %%
import json

# use the map() transformation to apply the same function to all rdds
# the function we want to run is the json.load() of the messages
#json_stream = socket_stream.map(""" --- """)
json_stream = socket_stream.map(lambda msg: json.load(msg))

# %% [markdown]
# It is possible to print some elements of each batch with `pprint()`. This can be used to explore the RDDs.

# %%
json_stream.pprint()

# %% [markdown]
# **Start the computations with `ssc.start()` and stop with `ssc.stop(stopSparkContext=False)`.**
#
# _Remember that once the StreamingContext has been stopped, it must be redefined anew if we want to restart the streaming computations._

# %%
ssc.start()
# Out:
# 23/05/10 07:43:29 WARN StreamingContext: StreamingContext has already been started
# [Stage 2:>                  (0 + 1) / 1][Stage 3:>                  (0 + 0) / 1]

# %%
ssc.stop(stopSparkContext=False)
# Out:
# 23/05/10 07:45:52 ERROR ReceiverTracker: Deregistered receiver for stream 0: Stopped by driver
# 23/05/10 07:45:53 ERROR TaskSchedulerImpl: Lost executor 0 on 172.18.0.3: Remote RPC client disassociated. Likely due to containers exceeding thresholds, or network issues. Check driver logs for WARN messages.
# 23/05/10 07:45:53 WARN TaskSetManager: Lost task 0.0 in stage 3.0 (TID 71) (172.18.0.3 executor 0): ExecutorLostFailure (executor 0 exited caused by one of the running tasks) Reason: Remote RPC client disassociated. Likely due to containers exceeding thresholds, or network issues. Check driver logs for WARN messages.
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704701200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704572400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704714800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704528400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704689800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704722200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704625400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704596400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704655800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704630400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704623000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704644400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704633600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704631200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704724000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704597600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704690400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704543800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704691800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704686200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704629600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704733200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704747200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704562200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704738800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704566800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704562600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704590200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704688200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704564200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704629400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704641600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704616400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704744800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704714400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704568800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704707000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704540800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704595000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704592400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704630800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704524000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704615600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704557200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704667400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704575000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704735400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704622200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704645200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704548000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704683800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704602800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704660600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704587000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704740800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704617400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704742600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704553600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704710000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704587600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704686000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704719000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704554600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704733000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704557800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704606800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704667600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704600000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704609600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704536000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704752200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704585600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704605600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704646000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704749600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704577000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704650400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704751600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704580000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704717200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704572800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704569200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704617800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704624200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704707200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704539800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704621600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704710600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704624800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704582600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704744400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704584600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704596200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704608600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704661000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704735200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704675200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704531800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704707600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704579600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704748800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704545000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704658800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704554400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704693600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704610400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704619200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704660800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704588000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704586400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704636800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704583000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704570200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704523600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704706000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704678800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704590400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704560400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704626600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704654400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704553800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704694800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704570800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704635000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704582000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704716200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704649200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704531200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704640800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704658600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704723200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704599200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704614800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704745200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704748400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704634600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704706600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704589600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704677800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704665800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704613000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704732000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704733800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704554200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704696000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704678200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704548200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704672800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704663000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704530000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704532000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704599400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704733400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704549000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704723800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704619800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704598400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704737400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704610200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704629200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704678600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704664000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704712800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704662000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704687000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704566400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704721800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704723000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704619600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704627200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704732600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704575400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704546000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704704600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704743400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704627800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704618600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704737800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704655000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704728800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704525000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704662200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704634000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704552400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704578800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704652600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704659200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704583400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704612800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704711000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704571600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704707800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704724400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704530400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704534800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704714600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704736600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704751200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704599800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704684400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704729400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704529400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704603000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704638200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704623600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704525400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704647200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704712200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704537800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704630600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704721000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704741000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704556800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704672600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704716600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704572200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704708400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704632800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704746400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704717400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704542600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704729800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704645000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704643600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704740400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704550200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704549600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704538000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704546400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704556200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704573600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704615200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704640600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704532200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704584400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704659400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704523800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704643000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704681600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704719200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704529200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704720400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704605200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704679200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704729600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704585400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704527200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704733600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704657400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704670400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704621800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704717800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704646200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704698800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704610600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704730000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704534400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704536400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704747400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704564400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704665000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704605000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704629800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704735800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704740000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704567000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704741400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704544200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704618200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704669400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704607000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704563800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704630200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704600400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704563200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704579200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704648800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704696800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704702000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704593200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704642400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704666200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704550000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704715400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704546200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704652800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704736800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704525600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704726800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704694400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704609000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704579400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704564000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704720600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704548800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704586600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704689200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704553200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704704400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704594000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704685800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704617200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704665400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704662400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704743200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704627400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704652000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704708800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704706800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704598200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704642000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704673600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704709600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704738400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704524200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704708000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704708200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704728200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704699200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704611000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704658000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704533400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704558600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704700600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704537200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704548600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704695000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704524400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704656400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704684600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704632200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704571400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704594600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704602000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704685000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704750600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704717600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704532800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704730800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704576400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704528200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704635600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704567400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704711800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704712600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704636600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704657000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704729200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704580800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704637600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704742200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704611600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704732200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704724800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704608400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704634200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704731800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704648400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704705800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704581000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704603800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704601800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704539400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704633800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704534000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704524600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704735000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704604000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704604800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704614600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704550600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704574400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704716800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704745600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704715600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704544600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704687800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704647000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704658200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704676000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704602600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704586000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704741600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704699000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704576000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704651800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704677600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704621200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704634400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704671200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704691200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704580600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704574600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704628600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704565400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704722800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704651600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704728400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704620600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704554800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704611800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704709000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704618000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704576200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704725200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704589800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704646600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704612000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704686800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704687400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704697000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704683200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704713200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704653200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704635200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704551800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704609200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704743600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704575600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704525800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704562000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704607200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704736400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704570400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704664400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704701000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704695800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704742800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704608800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704589400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704723400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704667800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704600200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704698400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704583600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704738600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704692200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704551000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704612200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704543400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704633400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704684000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704724600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704625800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704673800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704683600 !
# ...
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704584000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704559800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704640000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704609400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704537000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704639200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704568200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704542200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704635800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704679400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704680200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704736200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704730400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704526200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704618400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704666800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704692800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704533800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704559000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704613400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704649000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704703400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704549800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704643200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704564600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704699800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704682000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704719800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704710400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704711400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704604600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704621000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704693400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704526600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704687200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704596000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704664600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704536600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704545800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704603600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704692000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704678400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704642800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704597000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704670000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704705200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704586200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704675400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704561200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704601000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704679600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704626000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704694000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704541000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704563400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704552800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704682800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704676800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704639600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704660400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704676600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704572000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704744000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704551400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704560200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704672400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704743800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704668200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704592600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704718600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704726000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704701800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704742000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704655200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704560000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704578200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704747800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704697800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704550400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704526800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704582200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704577200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704535800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704637000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704588600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704684200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704660000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704526000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704740600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704677000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704737000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704732800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704710200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704640200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704574000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704632400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704698600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704567200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704730600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704720800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704674000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704577400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704570000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704538400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704591200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704611200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704595600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704703200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704579000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704654000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704600800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704579800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704709800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704713000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704735600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704734000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704748200 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704528600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704653600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704722000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704645600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704524800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704682400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704583800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704543600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704668400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704653000 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704666600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704646400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704534600 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704716400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704628400 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704668800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704585800 !
# 23/05/10 07:45:53 WARN BlockManagerMasterEndpoint: No more replicas available for input-0-1683704715800 !
# [Stage 3:>                                                          (0 + 1) / 1]
# 23/05/10 07:45:55 WARN TaskSetManager: Lost task 0.1 in stage 3.0 (TID 72) (172.18.0.3 executor 1): java.lang.Exception: Could not compute split, block input-0-1683704523600 of RDD 4 not found
# 	at org.apache.spark.errors.SparkCoreErrors$.rddBlockNotFoundError(SparkCoreErrors.scala:51)
# 	at org.apache.spark.rdd.BlockRDD.compute(BlockRDD.scala:51)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:365)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:329)
# 	at org.apache.spark.api.python.PythonRDD.compute(PythonRDD.scala:65)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:365)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:329)
# 	at org.apache.spark.api.python.PythonRDD.compute(PythonRDD.scala:65)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:365)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:329)
# 	at org.apache.spark.scheduler.ResultTask.runTask(ResultTask.scala:90)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:136)
# 	at org.apache.spark.executor.Executor$TaskRunner.$anonfun$run$3(Executor.scala:548)
# 	at org.apache.spark.util.Utils$.tryWithSafeFinally(Utils.scala:1504)
# 	at org.apache.spark.executor.Executor$TaskRunner.run(Executor.scala:551)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
#
# 23/05/10 07:45:55 ERROR TaskSetManager: Task 0 in stage 3.0 failed 4 times; aborting job

# %% [markdown]
# ## Working with Streaming data
#
# Now that we know how to stream data into Spark, let's explore how we can perform basic distributed operations on the data.
#
# However, before we can proceed, we need to make sure that we have properly restarted the `StreamingContext` object, as the connection between the socket and Spark will be lost when the context is stopped.
#
# To restart the streaming context, we need to:
# 1. Create a new `StreamingContext` object (we can reuse the `ssc` object in our case).
# 2. Point it to the correct TCP socket and port where the data is being streamed from.
# 3. Restart the Python producer application.
#
# Once the `StreamingContext` is properly set up and running, we can start applying distributed operations to the streaming data.

# %%
# create a new Spark StreamingContext with a batch wall-time of 2 seconds
ssc = """ --- """

# %%
# define the socket stream using the appropriate endpoint and port
socket_stream = """ --- """

# %%
# start the python producer script
### from the terminal/WSL shell

# %% [markdown]
# We now start listening on the TCP socket, interpreting the input data stream as `json` loads.
#
# **Remember to get rid of the `pprint()` action, that would otherwise be performed continously, dumping the input data into the Jupyter cells.**

# %%
# create a new json_stream object by reading the json loads from the socket
json_stream = socket_stream.map(""" --- """)

# %% [markdown]
# #### Converting Streaming Data to a DataFrame
#
# To make use of Spark's higher-level APIs, we can convert each batch of streaming data into a DataFrame.
#
# To do so, we'll first need to convert the numeric features of the incoming JSON data into Python floats and integers. This is a simple type cast operation that can be easily parallelized.
#
# After casting the data, we can create a `Row` object for each transaction using the resulting Python dictionary. These `Row` objects can then be used to create a DataFrame, allowing us to use Spark's higher-level APIs for data processing.

# %%
from pyspark.sql import Row

# create a row for each message 
#   convert each numerical value to the proper python type
#   create a row from each message
def create_row_rdd(t):
    t['amount'] = float(t['amount'])
    t['delta_t'] = float(t['delta_t'])
    t['flag'] = int(t['flag'])
    
    return Row(**t)
#** to create an RDD of rows?
#

# apply the transformation to the json_stream rdd
row_stream = json_stream.map(create_row_rdd)

# %% [markdown]
# The method `DStream.foreachRDD` can be used to apply custom transformations to each *batch* of data.
#
# In our case, we are insterested in converting each batch of data into a Spark DataFrame and perform operations, such as counting the number of transactions for each user.
#
# In this specific use-case, we can identify batches where a user has performed more than one transaction with the `flag` field equal to one as fraudulent. For simplicity, we will assume that these batches represent fraudulent activity.
#
# In reality, this might be a flag you might set on the fly using statig-rules or a ML-based model.

# %% [markdown]
# **NOTE**: If left unconstrained, Spark might want to create a very large number of partitions for this streaming application.
#
# Using way more partitions than necessary always results in a huge over-head due to the partition-to-partition communications.
#
# We can force Spark to use a small yet reasonable (given the problem and resources we have) number of partitions
# thus making it more efficient in the case of small workloads and few executors

# %%
# this line is a trick to force Spark to use a small number of partitions (4 in this example)
spark.conf.set("spark.sql.shuffle.partitions", 4)

# %% [markdown]
# ### Process each bach to identify possibly fraudolent transactions
#
#
# 1. convert the RDD into a DataFrame (provide the schema if necessary)
# 2. compute the _number of flagged transactions per batch per user_ (create a unique `userID` field as the combination of _FirstLastname_ to idenfity individual users)
# 3. identify all the "suspicios" transactions per user: all users with more than one flagged transaction per batch will be assigned a `isFraud` boolean variable
# 4. format the resulting `userID` and `isFraud` information in a DataFrame to mimick a "live-report" of the suspicious transactions

# %%
from pyspark.sql.functions import concat, col, lit, countDistinct

def process_batch(rdd):
    # convert rdd to df
    #   check the documentation and/or the Lecture2 notebook 
    #   for details on how to create and pass a schema to a dataframe   
    df = """ --- """
    #df = rdd.toDF(
            #schema = ...)
    
    # find number of transactions for each user when flag = 1 
    #    declare a new column to create a unique user identifier 
    #    this can be easily done by concatenating first- and last-name fields
    #    check the concat function from pyspark.sql.functions 
    num_transactions = """ --- """
    num_transactions = df.where(col('flag')==1\
                         .

    
    # find suspicious transactions
    #    filter only users with more than one transaction per batch
    #    create a "fraud" column with a value of 1 for the selected users (check the lit function)
    #    from the dataframe, project only the unique id and fraud columns
    sus_transactions = """ --- """
    
    # (trigger an automatic alert)
    # print the first 5 items of the resulting dataframe
    sus_transactions.show(5)

# %% [markdown]
# Finally, instruct Spark to execute this `process_batch` function **for each RDD** you will have in your DStream

# %%
row_stream.foreachRDD(process_batch)

# %% [markdown]
# Now you should be ready to start the spark streaming context

# %%
ssc.start()

# %%
# stop streaming context
ssc.stop(stopSparkContext=False)

# %% [markdown]
# ## Stop worker and master

# %%
sc.stop()
spark.stop()

# %% [markdown]
# Finally, use `docker compose down` to stop and clear all running containers.
